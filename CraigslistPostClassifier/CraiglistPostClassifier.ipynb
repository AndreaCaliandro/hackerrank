# %%
import sys
sys.path.insert(0, "/Users/andreacaliandro/PycharmProjects/hackerrank")

# %%
from read_files import read_file, json_like_input

data = read_file('/Users/andreacaliandro/PycharmProjects/hackerrank/CraigslistPostClassifier/data/training.json')
train_df = json_like_input(data)
train_df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>city</th>
#       <th>heading</th>
#       <th>section</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>New batteries C-S2 for Blackberry 7100/7130/87...</td>
#       <td>for-sale</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>*******   Brand New Original SAMSUNG GALAXY NO...</td>
#       <td>for-sale</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>SAMSUNG GALAXY SIII T-999 MARBLE WHITE T-MOBIL...</td>
#       <td>for-sale</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>Ipad mini 64gb 4g any sim unlock</td>
#       <td>for-sale</td>
#     </tr>
#     <tr>
# ...

# %%
for section in train_df['section'].unique():
    print section
# Out:
# for-sale
# housing
# community
# services

# %%
import pandas as pd
df = pd.DataFrame()
df['l'] = [1,2,3,4,5]
df['a'] = [1,2,3,7,5]
(df['l'] == df['a'])
len(df['l'])
# Out:
# 5

# %%
train_df.loc[train_df['section']=='housing', 'new_col'] = 5566*['good']
train_df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>city</th>
#       <th>heading</th>
#       <th>section</th>
#       <th>new_col</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>New batteries C-S2 for Blackberry 7100/7130/87...</td>
#       <td>for-sale</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>*******   Brand New Original SAMSUNG GALAXY NO...</td>
#       <td>for-sale</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
#       <td>SAMSUNG GALAXY SIII T-999 MARBLE WHITE T-MOBIL...</td>
#       <td>for-sale</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>cell-phones</td>
#       <td>newyork</td>
# ...

# %%
train_df.groupby('city').count
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>heading</th>
#       <th>section</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bangalore</th>
#       <td>585</td>
#       <td>585</td>
#       <td>585</td>
#     </tr>
#     <tr>
#       <th>chicago</th>
#       <td>4469</td>
#       <td>4469</td>
#       <td>4469</td>
#     </tr>
#     <tr>
#       <th>delhi</th>
#       <td>216</td>
#       <td>216</td>
#       <td>216</td>
#     </tr>
#     <tr>
#       <th>dubai.en</th>
#       <td>454</td>
#       <td>454</td>
#       <td>454</td>
#     </tr>
#     <tr>
#       <th>frankfurt.en</th>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>geneva.en</th>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#     </tr>
# ...

# %%
print '\n'.join(train_df['category'].values)
# Out:
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# cell-phones
# ...

# %%
train_df['heading'][0]
# Out:
# u'New batteries C-S2 for Blackberry 7100/7130/8700/Curve/Pearl'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer()
x = v.fit_transform(train_df['heading'][:10])

# %% [markdown]
# ## Example to familiarize

# %%
docs = ['Luca e Emma','LUCA non mangia','EMMA Non dorme']
x = v.fit_transform(docs)

# %%
x.toarray()
# Out:
# array([[ 0.        ,  0.70710678,  0.70710678,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.51785612,  0.68091856,  0.51785612],
#        [ 0.68091856,  0.51785612,  0.        ,  0.        ,  0.51785612]])

# %%
x_find = np.array([(1./3)*(np.log(4./3)+1), (1./3)*(np.log(4./2)+1), (1./3)*(np.log(4./3)+1)])
x_find/np.sqrt((x_find**2).sum())
# Out:
# array([ 0.51785612,  0.68091856,  0.51785612])

# %%
v.get_feature_names()
# Out:
# [u'dorme', u'emma', u'luca', u'mangia', u'non']

# %%
test_docs = ['Emma mangia', 'Luca dorme']
y = v.transform(test_docs)

# %%
y.toarray()
# Out:
# array([[ 0.        ,  0.60534851,  0.        ,  0.79596054,  0.        ],
#        [ 0.79596054,  0.        ,  0.60534851,  0.        ,  0.        ]])

# %%
y_find = np.array([(1./2)*(np.log(4./3)+1), (1./2)*(np.log(4./2)+1)])
y_find/np.sqrt((y_find**2).sum())
# Out:
# array([ 0.60534851,  0.79596054])

# %% [markdown]
# `v.transform(test_docs)` calculates the tf of each word according to the actual doc, while the idf is given by the training_doc sample.
